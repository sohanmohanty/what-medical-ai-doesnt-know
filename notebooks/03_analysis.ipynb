# %% [markdown]
# # 03 Analysis
#
# This notebook starts from the consolidated top-level results export and is intended for report-level slicing, comparison, and plotting.

# %%
import pandas as pd

metrics = pd.read_csv('../results/metrics.csv')
metrics[['dataset', 'model', 'mechanism', 'rate', 'source_file']].head()
