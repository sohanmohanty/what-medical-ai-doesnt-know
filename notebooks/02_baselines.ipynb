# %% [markdown]
# # 02 Baselines
#
# This notebook points to the clean-data baseline stage and the summary tables that anchor the rest of the report.

# %%
import pandas as pd

baseline = pd.read_csv('../results/metrics/clean_baseline_combined.csv')
baseline
