# %% [markdown]
# # 01 EDA
#
# This notebook is the lightweight entry point for inspecting the two core benchmark datasets used in the project.

# %%
from src.data_loading import load_wdbc, load_statlog_heart

X_wdbc, y_wdbc, _ = load_wdbc()
X_statlog, y_statlog, _ = load_statlog_heart()

print('WDBC:', X_wdbc.shape, y_wdbc.value_counts().to_dict())
print('Statlog Heart:', X_statlog.shape, y_statlog.value_counts().to_dict())
X_wdbc.head()
